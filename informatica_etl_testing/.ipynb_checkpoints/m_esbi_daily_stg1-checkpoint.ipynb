# %%
from sqlalchemy import create_engine, MetaData, Table, Column, ForeignKey, select, func, Integer, String, DateTime
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
import pandas as pd
import dask.dataframe as dd

# %%
# 1. Input: ES_ODS_OWNER.ES_TAGS_DIM

# LDAP Version:
orc_es_dw_engine = create_engine('oracle://ES_DW_OWNER:.8+4=EOV@PGSDWD')
es_dw_conn = orc_es_dw_engine.connect()

# %%
# LDAP Version:
orc_es_dw_engine = create_engine('oracle+cx_oracle://ES_DW_OWNER:.8+4=EOV@PGSDWD')
es_dw_conn = orc_es_dw_engine.connect()

# %%
# LDAP Version:
orc_es_dw_engine = create_engine('oracle+cx_oracle://ES_DW_OWNER:.8+4=EOV@PGSDWD.FPL.COM')
es_dw_conn = orc_es_dw_engine.connect()

# %%
# Need to define SQL Queries per table:
# Reflect the tables from the connection

# produce our own MetaData object
es_dw_metadata = MetaData()
es_dw_metadata.reflect(orc_es_dw_engine, only=['es_tags_dim', 'es_plant_dim', 'es_plant_fact'])

# we can then produce a set of mappings from this MetaData.
es_dw_base = automap_base(metadata=es_dw_metadata)

# calling prepare() just sets up mapped classes and relationships.
es_dw_base.prepare()

for tablename in es_dw_base.classes:
    print(tablename)
# Out:
# <class 'sqlalchemy.ext.automap.es_tags_dim'>
# <class 'sqlalchemy.ext.automap.es_plant_dim'>
# <class 'sqlalchemy.ext.automap.es_plant_fact'>

# %%
# mapped classes are now created with names by default
# matching that of the table name.
tags_dim = es_dw_base.classes.es_tags_dim
plant_dim = es_dw_base.classes.es_plant_dim

plant_fact = es_dw_base.classes.es_plant_fact


for c in tags_dim.__table__.columns:
    print(c)

print()

for c in plant_dim.__table__.columns:
    print(c)

print()

for c in plant_fact.__table__.columns:
    print(c)
# Out:
# es_tags_dim.tag_id
# es_tags_dim.tag_name
# es_tags_dim.plant_id
# es_tags_dim.tag_type
# es_tags_dim.tag_desc
# es_tags_dim.server_name
# es_tags_dim.pi_method
# es_tags_dim.create_date
# es_tags_dim.created_by
# es_tags_dim.update_date
# es_tags_dim.updated_by
# es_tags_dim.version
#
# es_plant_dim.id
# es_plant_dim.plant_id
# es_plant_dim.plant_code
# es_plant_dim.plant_name
# es_plant_dim.plant_capacity
# es_plant_dim.plant_capacity_unit
# es_plant_dim.co_date
# es_plant_dim.company
# es_plant_dim.asset_sk
# es_plant_dim.inverter_count
# es_plant_dim.rack_count
# es_plant_dim.derate_capacity
# es_plant_dim.mwh_capacity
# es_plant_dim.regulation
# es_plant_dim.operation_mode
# es_plant_dim.server_name
# es_plant_dim.city
# es_plant_dim.state_code
# es_plant_dim.country
# es_plant_dim.timezone
# es_plant_dim.status
# es_plant_dim.create_date
# es_plant_dim.created_by
# es_plant_dim.update_date
# es_plant_dim.updated_by
# es_plant_dim.version
#
# es_plant_fact.asset_sk
# es_plant_fact.plant_id
# es_plant_fact.timestamplocal
# es_plant_fact.timestamputc
# es_plant_fact.loadtimestamputc
# es_plant_fact.create_date
# es_plant_fact.created_by
# es_plant_fact.update_date
# es_plant_fact.updated_by
# es_plant_fact.datetimesk
# es_plant_fact.datesklocal
# es_plant_fact.datesk_utc
# es_plant_fact.secsk_local
# es_plant_fact.secsk_utc
# es_plant_fact.energy_delivered_mwh
# es_plant_fact.energy_received_mwh
# es_plant_fact.forced_outage_hours
# es_plant_fact.maintenance_outage_hours
# es_plant_fact.omc_outage_hours
# es_plant_fact.event_type_id
# es_plant_fact.status_flag_id
# es_plant_fact.state_of_charge
# es_plant_fact.downtime_equip_min
# es_plant_fact.aux_power
# es_plant_fact.mw_pricing
# es_plant_fact.site_var
# es_plant_fact.rsd_type_id
# es_plant_fact.rsd_maintenance_hours
# es_plant_fact.rsd_forced_hours
# es_plant_fact.rsd_market_hours
# es_plant_fact.comm_outage_hours
# es_plant_fact.rsd_comm_hours
# es_plant_fact.downtime_rsd_min
# es_plant_fact.downtime_perf_min

# %%
# 1. Input: ES_ODS_OWNER.ES_SCADA_STG1
# LDAP Version:
es_ods_engine = create_engine('oracle://ES_ODS_OWNER:yD8J;Czg@PGSDWD')
es_ods_conn = es_ods_engine.connect()

# %%
# Need to define SQL Queries per table:
# Reflect the tables from the connection
# produce our own MetaData object
es_ods_metadata = MetaData()
# es_ods_metadata.reflect(es_ods_engine, only=['es_scada_stg1'])


scada_stg1_table = Table('es_scada_stg1', es_ods_metadata,
                         Column("plant_id", Integer, primary_key=True),
                         Column("plant_code", String, primary_key=True),
                         Column("tagname", String, primary_key=True),
                         autoload=True, autoload_with=es_ods_engine)


dte_data_table = Table('es_dte_data', es_ods_metadata,
Column("plant_id", Integer, primary_key=True),
autoload=True, autoload_with=es_ods_engine, extend_existing=True)

print([c.name for c in scada_stg1_table.columns])
#es_ods_metadata.reflect(es_ods_engine, only=['es_scada_stg1'])

# we can then produce a set of mappings from this MetaData.
es_ods_base = automap_base(metadata=es_ods_metadata)

# calling prepare() just sets up mapped classes and relationships.
es_ods_base.prepare()

for tablename in es_ods_base.classes:
    print(tablename)
# Out:
# ['plant_id', 'plant_code', 'tagname', 'value', 'timestamplocal', 'timestamputc', 'create_date', 'update_date', 'created_by', 'updated_by']
# <class 'sqlalchemy.ext.automap.es_scada_stg1'>
# <class 'sqlalchemy.ext.automap.es_dte_data'>

# %%
from sqlalchemy.orm import mapper

# map core table to orm 
class SCADA_STG1_Class(object):
    pass

mapper(SCADA_STG1_Class, scada_stg1_table,
    polymorphic_on=scada_stg1_table.c.plant_id,
    properties={
        'alt':scada_stg1_table.c.plant_code
    })
    
#es_ods_metadata.reflect(es_ods_engine, only=['es_scada_stg1'])

# we can then produce a set of mappings from this MetaData.
es_ods_base = automap_base(metadata=es_ods_metadata)

# calling prepare() just sets up mapped classes and relationships.
es_ods_base.prepare()

for tablename in es_ods_base.classes:
    print(tablename)

# %%
# mapped classes are now created with names by default
# matching that of the table name.
scada_stg1 = es_ods_base.classes.es_scada_stg1

for c in scada_stg1.__table__.columns:
    print(c)

print()


dte_data = es_ods_base.classes.es_dte_data

for c in dte_data.__table__.columns:
    print(c)

print()
# Out:
# es_scada_stg1.plant_id
# es_scada_stg1.plant_code
# es_scada_stg1.tagname
# es_scada_stg1.value
# es_scada_stg1.timestamplocal
# es_scada_stg1.timestamputc
# es_scada_stg1.create_date
# es_scada_stg1.update_date
# es_scada_stg1.created_by
# es_scada_stg1.updated_by
#
# es_dte_data.start_date_time_utc
# es_dte_data.end_date_time_utc
# es_dte_data.plant_id
# es_dte_data.start_date_time_local
# es_dte_data.end_date_time_local
# es_dte_data.energy_delivered_mwh
# es_dte_data.energy_received_mwh
# es_dte_data.event_id
# es_dte_data.downtime_hours_duration
# es_dte_data.notes
# es_dte_data.certify
# es_dte_data.create_date
# es_dte_data.created_by
# es_dte_data.update_date
# es_dte_data.updated_by
# es_dte_data.available_inv_min
# es_dte_data.state_of_charge
# es_dte_data.downtime_hrs_areg
# es_dte_data.downtime_hrs_batteries
# es_dte_data.rsd_hrs
# es_dte_data.downtime_hrs_equip
# es_dte_data.plant_code
# es_dte_data.status_flag
# es_dte_data.rsd_type_id

# %%
from sqlalchemy.orm import sessionmaker, scoped_session, Session
import datetime as dt

es_ods_session_factory = sessionmaker(bind=es_ods_engine)
es_ods_session = scoped_session(es_ods_session_factory)


scada_stg1_data = es_ods_session.query(scada_stg1).limit(10)

for u in scada_stg1_data:
    print(u.__dict__)
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x1A237810>, 'value': '1.000000000000000', 'update_date': datetime.datetime(2018, 12, 4, 2, 3, 55), 'plant_id': 25069, 'timestamplocal': datetime.datetime(2018, 10, 31, 10, 58), 'created_by': 'SOLAR_ETL', 'plant_code': 'BGM1', 'timestamputc': None, 'updated_by': 'SOLAR_ETL', 'tagname': 'BGM_BATTxxx_SUB0001_52M2_Breaker_Position', 'create_date': datetime.datetime(2018, 12, 4, 2, 3, 55)}

# %%
from sqlalchemy.orm import sessionmaker, scoped_session, Session
import datetime as dt

es_ods_session_factory = sessionmaker(bind=es_ods_engine)
es_ods_session = scoped_session(es_ods_session_factory)


dte_data_recs = es_ods_session.query(dte_data).filter_by(updated_by='AXO01RA').all()

print(dte_data_recs)
# Out:
# [<sqlalchemy.ext.automap.es_dte_data object at 0x135B7A30>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7A90>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7AD0>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7B10>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7B50>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7BB0>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7BF0>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7C30>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7C70>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7B90>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7CD0>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7D10>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7D50>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7D90>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7DD0>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7E10>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7E50>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7E90>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7ED0>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7F10>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7F50>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7F90>, <sqlalchemy.ext.automap.es_dte_data object at 0x135B7FD0>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4030>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4070>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C40B0>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C40F0>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4190>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C41D0>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4210>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4250>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4290>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C42D0>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4310>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4350>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4390>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C43D0>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4410>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4450>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4490>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C44D0>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4510>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4550>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4590>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C45D0>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4610>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4650>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4690>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C46D0>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4710>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4750>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4790>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C47D0>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4810>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4850>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4890>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C48D0>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4910>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4950>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4990>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C49D0>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4A10>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4A50>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4A90>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4AD0>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4B10>, <sqlalchemy.ext.automap.es_dte_data object at 0x135C4B50>, <sqlalchemy.ext.automap.es_dte_data object at  ...

# %%
import time

start = time.time()

es_ods_engine.execute(scada_stg1_table.insert(),scada_stg1_record)

duration = time.time() - start

print('SQLAlchemy Core - total time: {:.2f} seconds'.format(duration))
# Out:
# SQLAlchemy Core - total time: 0.08 seconds

# %%
from sqlalchemy.orm import sessionmaker
from sqlalchemy.orm import Session

Session = sessionmaker(bind=orc_es_dw_engine)
session = Session() 

# Test session access:
pf_recs = session.query(tags_dim.tag_id, tags_dim.tag_name, tags_dim.plant_id, tags_dim.server_name, tags_dim.pi_method).limit(100)

'''
with data as
(
select a.TAG_ID, a.TAG_NAME, a.PLANT_ID,a.SERVER_NAME,a.PI_METHOD
from
es_dw_owner.es_tags_dim a
$$SQLADDON)
,dummy_time as
(
select  to_date('$$START_TIME','mm/dd/yyyy hh24:mi:ss')+(level/1440) start_date
from dual
connect by level <=$$Minutes)
select * from data,
dummy_time
'''

for rec in pf_recs:
    print(rec)
# Out:
# (81.0, 'BEH_BATTxxx_SUB0001_ION_AUX_KW', 1227.0, 'ewis-battne', 'GetArchiveValue')
# (82.0, 'BEH_PPCxxxx_Site_AVG_SOC', 1227.0, 'ewis-battne', 'GetArchiveValue')
# (83.0, 'BEH_BATTxxx_SUB0001_ION_SITE_KVAR', 1227.0, 'ewis-battne', 'GetArchiveValue')
# (84.0, 'BEH_BATTxxx_SUB0001_ION_SITE_KW', 1227.0, 'ewis-battne', 'GetArchiveValue')
# (87.0, 'BEH_BATTxxx_SUB0001_SEL487B_Breaker_Status', 1227.0, 'ewis-battne', 'GetArchiveValue')
# (175.0, 'BPB_BATTxxx_ESS_Cycle_Count', 1228.0, 'ewis-battne', 'GetArchiveValue')
# (177.0, 'BBR1_PAR890x_SKD0000_PCS_TOTAL_AVAILABLE', 502.0, 'EWIS-battjb', 'GetArchiveValue')
# (181.0, 'BBR1_M115xxx_SUB0001_F3_MVAR', 502.0, 'EWIS-battjb', 'GetArchiveValue')
# (201.0, 'DummyTag', 1230.0, 'ewis-battne', 'GetArchiveValue')
# (231.0, 'BPE_BATTxxx_SUB0001_SEL351S_52A_Breaker_Status', 1231.0, 'ewis-battne', 'GetArchiveValue')
# (232.0, 'BPE_BATTxxx_SUB0001_ION_SITE_KW', 1231.0, 'ewis-battne', 'GetArchiveValue')
# (233.0, 'BPE_BATTxxx_SUB0001_ION_SITE_KVAR', 1231.0, 'ewis-battne', 'GetArchiveValue')
# (234.0, 'BPE_BATTxxx_SUB0001_ION_AUX_KW', 1231.0, 'ewis-battne', 'GetArchiveValue')
# (235.0, 'BPE_xxxxxxx_INV0000_Site_Avail_Count', 1231.0, 'ewis-battne', 'GetArchiveValue')
# (236.0, 'BPE_BATTxxx_ESS_Racks_In_Service', 1231.0, 'ewis-battne', 'GetArchiveValue')
# (237.0, 'BPE_BATTxxx_INV0000_MW_Sum', 1231.0, 'ewis-battne', 'GetArchiveValue')
# (238.0, 'BPE_BATTxxx_INV0000_MVAR_Sum', 1231.0, 'ewis-battne', 'GetArchiveValue')
# (239.0, 'BPE_PPCxxxx_MW_SCHED_TODAY_0', 1231.0, 'ewis-battne', 'GetArchiveValue')
# (240.0, 'BPE_PPCxxxx_SITE_kWh_DEL_Monthly', 1231.0, 'ewis-battne', 'GetArchiveValue')
# (241.0, 'BPE_PPCxxxx_SITE_kWh_DEL_Today', 1231.0, 'ewis-battne', 'GetArchiveValue')
# (242.0, 'BPE_BATTxxx_SUB0001_ION_SITE_kWh_DEL', 1231.0, 'ewis-battne', 'GetArchiveValue')
# (243.0, 'BPE_BATTxxx_SUB0001_ION_SITE_kWh_REC', 1231.0, 'ewis-battne', 'GetArchiveValue')
# (244.0, 'BPE_BATTxxx_SUB0001_ION_SITE_kWh_DEL_REC', 1231.0, 'ewis-battne', 'GetArchiveValue')
# (245.0, 'BPE_PPCxxxx_HMI_REAL_TIME_PRICE', 1231.0, 'ewis-battne', 'GetArchiveValue')
# (246.0, 'BPE_PPCxxxx_Site_AVG_SOC', 1231.0, 'ewis-battne', 'GetArchiveValue')
# (247.0, 'BPE_PPCxxxx_Site_Service_SOC', 1231.0, 'ewis-battne', 'GetArchiveValue')
# (620.0, 'BFT_BATTxxx_SUB0001_52M3_Breaker_position', 31961.0, 'ewis-battne', 'GetArchiveValue')
# (621.0, 'BFT_BATTxxx_ESS_SUB_KW', 31961.0, 'ewis-battne', 'GetArchiveValue')
# (622.0, 'BFT_BATTxxx_SUB0001_MVAR_Total', 31961.0, 'ewis-battne', 'GetArchiveValue')
# (623.0, 'BFT_BATTxxx_SUB0001_Battery_Station_KW', 31961.0, 'ewis-battne', 'GetArchiveValue')
# (624.0, 'BFT_xxxxxxx_INV0000_Site_Avail_Count', 31961.0, 'ewis-battne', 'GetArchiveValue')
# (625.0, 'BFT_BATTxxx_ESS_Racks_In_Service', 31961.0, 'ewis-battne', 'GetArchiveValue')
# (626.0, 'BFT_BATTxxx_SUB0001_Battery_Collector_RMB_KW', 31961.0, 'ewis-battne', 'GetArchiveValue')
# (627.0, 'BFT_BATTxxx_SUB0001_PJM _AREG', 31961.0, 'ewis-battne', 'GetArchiveValue')
# (628.0, 'BFT_BATTxxx_SUB0001_PJM _AREG', 31961.0, 'ewis-battne', 'GetArchiveValue')
# (629.0, 'BFT_BATTxxx_SUB0001_PJM_TREG', 31961.0, 'ewis-battne', 'GetArchiveValue')
# (630.0, 'BFT_BATTxxx_SUB0001_PJM_CREG', 31961.0, 'ewis-battne', 'GetArchiveValue')
# (631.0, 'BFT_BATTxxx_SUB0001_PJM_REGD', 31961.0, 'ewis-battne', 'GetArchiveValue')
# (720.0, 'BBS_BATTxxx_ESS_ERCOT_REGD_Resp', 50086.0, 'ewis-battne', 'GetArchiveValue')
# (632.0, 'BFT_BATTxxx_ESS_Rack_Avg_SOC', 31961.0, 'ewis-battne', 'GetArchiveValue')
# (633.0, 'BFT_BATTxxx_ESS_Rack_Avg_Service_SOC', 31961.0, 'ewis-battne', 'GetArchiveValue')
# (723.0, 'BBS_BATTxxx_ESS_ERCOT_REGUP_Resp', 50086.0, 'ewis-battne', 'GetArchiveValue')
# (725.0, 'BBS_BATTxxx_ESS_FREQ_REG_MW_SP', 50086.0, 'ewis-battne', 'GetArchiveValue')
# (727.0, 'BBS_BATTxxx_ESS_MW_Available', 50086.0, 'ewis-battne', 'GetArchiveValue')
# (729.0, 'BBS_BATTxxx_ESS_Rack_Avg_SOC', 50086.0, 'ewis-battne', 'GetArchiveValue')
# (731.0, 'BBS_BATTxxx_ESS_Rack_Avg_Service_SOC', 50086.0, 'ewis-battne', 'GetArchiveValue')
# (733.0, 'BBS_BATTxxx_ESS_Racks_In_Service', 50086.0, 'ewis-battne', 'GetArchiveValue')
# (735.0, 'BBS_BATTxxx_INV0000_MW_Sum', 50086.0, 'ewis-battne', 'GetArchiveValue')
# (737.0, 'BBS_BATTxxx_SUB0001_52M3_Breaker_Position', 50086.0, 'ewis-battne', 'GetArchiveValue')
# (739.0, 'BBS_BATTxxx_SUB0001_Battery_Station_KW', 50086.0, 'ewis-battne', 'GetArchiveValue')
# (741.0, 'BBS_BATTxxx_SUB0001_MVAR_Total', 50086.0, 'ewis-battne', 'GetArchiveValue')
# (743.0, 'BBS_BATTxxx_SUB0001_MW_Total', 50086.0, 'ewis-battne', 'GetArchiveValue')
# (745.0, 'BBS_xxxxxxx_INV0000_Site_Avail_Count', 50086.0, 'ewis-battne', 'GetArchiveValue')
# (1.0, 'BMY_BATTxxx_SUB0001_52M2_Breaker_Position', 34044.0, 'ewis-battne', 'GetArchiveValue')
# (2.0, 'BMY_BATTxxx_SUB0001_KW_Total', 34044.0, 'ewis-battne', 'GetArchiveValue')
# (3.0, 'BMY_BATTxxx_SUB0001_KVAR_Total', 34044.0, 'ewis-battne', 'GetArchiveValue')
# (4.0, 'BMY_BATTxxx_SUB0001_Battery_Station_KW', 34044.0, 'ewis-battne', 'GetArchiveValue')
# (5.0, 'BMY_xxxxxxx_INV0000_Site_Avail_Count', 34044.0, 'ewis-battne', 'GetArchiveValue')
# (6.0, 'BMY_BATTxxx_ESS_Racks_In_Service', 34044.0, 'ewis-battne', 'GetArchiveValue')
# (7.0, 'BMY_BATTxxx_SUB0001_PJM_AREG', 34044.0, 'ewis-battne', 'GetArchiveValue')
# (8.0, 'BMY_BATTxxx_SUB0001_PJM_AREG', 34044.0, 'ewis-battne', 'GetArchiveValue')
# (9.0, 'BMY_BATTxxx_SUB0001_PJM_TREG', 34044.0, 'ewis-battne', 'GetArchiveValue')
# (10.0, 'BMY_BATTxxx_SUB0001_PJM_CREG', 34044.0, 'ewis-battne', 'GetArchiveValue')
# (11.0, 'BMY_BATTxxx_SUB0001_PJM_REGD', 34044.0, 'ewis-battne', 'GetArchiveValue')
# (12.0, 'BMY_BATTxxx_ESS_Rack_Avg_SOC', 34044.0, 'ewis-battne', 'GetArchiveValue')
# (13.0, 'BMY_BATTxxx_ESS_Rack_EFF_SOC', 34044.0, 'ewis-battne', 'GetArchiveValue')
# (480.0, 'BCB_BATTxxx_SUB0001_MW_Total', 48724.0, 'ewis-battne', 'GetArchiveValue')
# (481.0, 'BCB_BATTxxx_SUB0001_MVAR_Total', 48724.0, 'ewis-battne', 'GetArchiveValue')
# (482.0, 'BCB_BATTxxx_SUB0001_Battery_Station_KW', 48724.0, 'ewis-battne', 'GetArchiveValue')
# (483.0, 'BCB_xxxxxxx_INV0000_Site_Avail_Count', 48724.0, 'ewis-battne', 'GetArchiveValue')
# (484.0, 'BCB_BATTxxx_ESS_Racks_In_Service', 48724.0, 'ewis-battne', 'GetArchiveValue')
# (485.0, 'BCB_BATTxxx_INV0000_MW_Sum', 48724.0, 'ewis-battne', 'GetArchiveValue')
# (486.0, 'BCB_BATTxxx_SUB0001_ISO_AREG_HI', 48724.0, 'ewis-battne', 'GetArchiveValue')
# (487.0, 'BCB_BATTxxx_SUB0001_ISO_AREG_LOW', 48724.0, 'ewis-battne', 'GetArchiveValue')
# (488.0, 'BCB_BATTxxx_ESS_MW_Available', 48724.0, 'ewis-battne', 'GetArchiveValue')
# (489.0, 'BCB_BATTxxx_SUB0001_ISO_CREG', 48724.0, 'ewis-battne', 'GetArchiveValue')
# (490.0, 'BCB_BATTxxx_SUB0001_ISO_REGD', 48724.0, 'ewis-battne', 'GetArchiveValue')
# (491.0, 'BCB_BATTxxx_ESS_Rack_Avg_SOC', 48724.0, 'ewis-battne', 'GetArchiveValue')
# (479.0, 'BCB_BATTxxx_SUB0001_52M1_Breaker_Position', 48724.0, 'ewis-battne', 'GetArchiveValue')
# (492.0, 'BCB_BATTxxx_ESS_Rack_Avg_Service_SOC', 48724.0, 'ewis-battne', 'GetArchiveValue')
# (493.0, 'BCB_WYM_BATTxxx_Plant_AMPS', 48724.0, 'ewis-battne', 'GetArchiveValue')
# (680.0, 'DUMMY', 26768.0, 'ewis-SolarNE', 'GetArchiveValue')
# (667.0, 'MC1_Batt_Inv2_AC_Breaker_State', 26768.0, 'ewis-SolarNE', 'GetArchiveValue')
# (668.0, 'SPS1_MC_MW', 26768.0, 'ewis-SolarNE', 'GetArchiveValue')
# (669.0, 'SPS1_MC_MVAR', 26768.0, 'ewis-SolarNE', 'GetArchiveValue')
# (641.0, 'BGM_BATTxxx_SUB0001_52M2_Breaker_Position', 25069.0, 'ewis-battne', 'GetArchiveValue')
# (642.0, 'BGM_BATTxxx_SUB0001_KW_Total', 25069.0, 'ewis-battne', 'GetArchiveValue')
# (643.0, 'BGM_BATTxxx_SUB0001_MVAR_Total', 25069.0, 'ewis-battne', 'GetArchiveValue')
# (644.0, 'BGM_BATTxxx_SUB0001_Battery_Station_KW', 25069.0, 'ewis-battne', 'GetArchiveValue')
# (645.0, 'BGM_xxxxxxx_INV0000_Site_Avail_Count', 25069.0, 'ewis-battne', 'GetArchiveValue')
# (646.0, 'BGM_BATTxxx_ESS_Racks_In_Service', 25069.0, 'ewis-battne', 'GetArchiveValue')
# (647.0, 'BGM_BATTxxx_INV0000_MW_Sum', 25069.0, 'ewis-battne', 'GetArchiveValue')
# (648.0, 'BGM_BATTxxx_SUB0001_PJM_AREG', 25069.0, 'ewis-battne', 'GetArchiveValue')
# (649.0, 'BGM_BATTxxx_SUB0001_PJM_AREG', 25069.0, 'ewis-battne', 'GetArchiveValue')
# (650.0, 'BGM_BATTxxx_SUB0001_PJM_TREG', 25069.0, 'ewis-battne', 'GetArchiveValue')
# (651.0, 'BGM_BATTxxx_SUB0001_PJM_CREG', 25069.0, 'ewis-battne', 'GetArchiveValue')
# (652.0, 'BGM_BATTxxx_SUB0001_PJM_REGD', 25069.0, 'ewis-battne', 'GetArchiveValue')
# (653.0, 'BGM_BATTxxx_ESS_Rack_Avg_SOC', 25069.0, 'ewis-battne', 'GetArchiveValue')
# (654.0, 'BGM_BATTxxx_ESS_Rack_Avg_Service_SOC', 25069.0, 'ewis-battne', 'GetArchiveValue')
# (670.0, 'MC1_BATTxxx_INV0000_Site_Avail_Count', 26768.0, 'ewis-SolarNE', 'GetArchiveValue')

# %%
es_tags_dim_res = es_dw_conn.execute("select td.plant_id, td.tag_name, td.server_name, td.pi_method, pd.plant_code from ES_TAGS_DIM td JOIN ES_PLANT_DIM pd ON td.PLANT_ID = pd.PLANT_ID AND pd.status = 'A'")

# LOAD RESULTS  FOM TABLE INTO df:
#es_tags_df = pd.read_sql_query('select TAG_ID, TAG_NAME, PLANT_ID, SERVER_NAME, PI_METHOD, CREATE_DATE from ES_TAGS_DIM', es_dw_conn)

es_tags_df = pd.DataFrame(es_tags_dim_res.fetchall())
es_tags_df.columns = [k.upper() for k in es_tags_dim_res.keys()]
# len(es_tags_df['TAG_NAME'].unique())
es_tags_ddf = dd.from_pandas(es_tags_df, npartitions=6)
es_tags_ddf.divisions 
# es_tags_df.head(50)
# Out:
# (0, 31, 62, 93, 124, 155, 183)

# %%
# 2. Perform Reflection / ORM Mapping

# Keep only the fields TAG_ID, TAG_NAME, PLANT_ID, SERVER_NAME, PI_METHOD, CREATE_DATE
es_tags_df = es_tags_df.filter(items=['TAG_ID', 'TAG_NAME', 'PLANT_ID', 'SERVER_NAME', 'PI_METHOD', 'CREATE_DATE'])
# es_tags_df = es_tags_df.loc[(es_tags_df['PLANT_ID']==48724) & (es_tags_df['TAG_NAME'].isin(['BCB_BATTxxx_SUB0001_ISO_AREG_HI', 'BCB_BATTxxx_SUB0001_ISO_AREG_LOW']))]
es_tags_df.head(100)
# Out:
#                                           TAG_NAME  PLANT_ID   SERVER_NAME  \
# 0                   BEH_BATTxxx_SUB0001_ION_AUX_KW      1227   ewis-battne
# 1                         BEH_PPCxxxx_Site_AVG_SOC      1227   ewis-battne
# 2                BEH_BATTxxx_SUB0001_ION_SITE_KVAR      1227   ewis-battne
# 3                  BEH_BATTxxx_SUB0001_ION_SITE_KW      1227   ewis-battne
# 4       BEH_BATTxxx_SUB0001_SEL487B_Breaker_Status      1227   ewis-battne
# 5                      BPB_BATTxxx_ESS_Cycle_Count      1228   ewis-battne
# 6                                         DummyTag      1230   ewis-battne
# 7   BPE_BATTxxx_SUB0001_SEL351S_52A_Breaker_Status      1231   ewis-battne
# 8                  BPE_BATTxxx_SUB0001_ION_SITE_KW      1231   ewis-battne
# 9                BPE_BATTxxx_SUB0001_ION_SITE_KVAR      1231   ewis-battne
# 10                  BPE_BATTxxx_SUB0001_ION_AUX_KW      1231   ewis-battne
# 11            BPE_xxxxxxx_INV0000_Site_Avail_Count      1231   ewis-battne
# 12                BPE_BATTxxx_ESS_Racks_In_Service      1231   ewis-battne
# 13                      BPE_BATTxxx_INV0000_MW_Sum      1231   ewis-battne
# 14                    BPE_BATTxxx_INV0000_MVAR_Sum      1231   ewis-battne
# 15                    BPE_PPCxxxx_MW_SCHED_TODAY_0      1231   ewis-battne
# 16                BPE_PPCxxxx_SITE_kWh_DEL_Monthly      1231   ewis-battne
# 17                  BPE_PPCxxxx_SITE_kWh_DEL_Today      1231   ewis-battne
# 18            BPE_BATTxxx_SUB0001_ION_SITE_kWh_DEL      1231   ewis-battne
# 19            BPE_BATTxxx_SUB0001_ION_SITE_kWh_REC      1231   ewis-battne
# 20        BPE_BATTxxx_SUB0001_ION_SITE_kWh_DEL_REC      1231   ewis-battne
# 21                 BPE_PPCxxxx_HMI_REAL_TIME_PRICE      1231   ewis-battne
# 22                        BPE_PPCxxxx_Site_AVG_SOC      1231   ewis-battne
# 23                    BPE_PPCxxxx_Site_Service_SOC      1231   ewis-battne
# 24       BFT_BATTxxx_SUB0001_52M3_Breaker_position     31961   ewis-battne
# 25                          BFT_BATTxxx_ESS_SUB_KW     31961   ewis-battne
# 26                  BFT_BATTxxx_SUB0001_MVAR_Total     31961   ewis-battne
# 27          BFT_BATTxxx_SUB0001_Battery_Station_KW     31961   ewis-battne
# 28            BFT_xxxxxxx_INV0000_Site_Avail_Count     31961   ewis-battne
# 29                BFT_BATTxxx_ESS_Racks_In_Service     31961   ewis-battne
# ..                                             ...       ...           ...
# 70                 BCB_BATTxxx_SUB0001_ISO_AREG_HI     48724   ewis-battne
# 71                BCB_BATTxxx_SUB0001_ISO_AREG_LOW     48724   ewis-battne
# 72                    BCB_BATTxxx_ESS_MW_Available     48724   ewis-battne
# 73                    BCB_BATTxxx_SUB0001_ISO_CREG     48724   ewis-battne
# 74                    BCB_BATTxxx_SUB0001_ISO_REGD     48724   ewis-battne
# 75                    BCB_BATTxxx_ESS_Rack_Avg_SOC     48724   ewis-battne
# 76       BCB_BATTxxx_SUB0001_52M1_Breaker_Position     48724   ewis-battne
# 77            BCB_BATTxxx_ESS_Rack_Avg_Service_SOC     48724   ewis-battne
# 78                      BCB_WYM_BATTxxx_Plant_AMPS     48724   ewis-battne
# 79                                           DUMMY     26768  ewis-SolarNE
# 80                  MC1_Batt_Inv2_AC_Breaker_State     26768  ewis-SolarNE
# 81                                      SPS1_MC_MW     26768  ewis-SolarNE
# 82                                    SPS1_MC_MVAR     26768  ewis-SolarNE
# 83       BGM_BATTxxx_SUB0001_52M2_Breaker_Position     25069   ewis-battne
# 84                    BGM_BATTxxx_SUB0001_KW_Total     25069   ewis-battne
# 85                  BGM_BATTxxx_SUB0001_MVAR_Total     25069   ewis-battne
# 86          BGM_BATTxxx_SUB0001_Battery_Station_KW     25069   ewis-battne
# 87            BGM_xxxxxxx_INV0000_Site_Avail_Count     25069   ewis-battne
# 88                BGM_BATTxxx_ESS_Racks_In_Service     25069   ewis-battne
# 89                      BGM_BATTxxx_INV0000_MW_Sum     25069   ewis-battne
# 90                    BGM_BATTxxx_SUB0001_PJM_AREG     25069   ewis-battne
# 91                    BGM_BATTxxx_SUB0001_PJM_AREG     25069   ewis-battne
# 92                    BGM_BATTxxx_SUB0001_PJM_TREG     25069   ewis-battne
# 93                    BGM_BATTxxx_SUB0001_PJM_CREG     25069   ewis-battne
# 94                    BGM_BATTxxx_SUB0001_PJM_REGD     25069   ewis-battne
# 95                    BGM_BATTxxx_ESS_Rack_Avg_SOC     25069   ewis-battne
# 96            BGM_BATTxxx_ESS_Rack_Avg_Service_SOC     25069   ewis-battne
# 97            MC1_BATTxxx_INV0000_Site_Avail_Count     26768  ewis-SolarNE
# 98                          MC1_BATT_MC_Inv2_Power     26768  ewis-SolarNE
# 99                            MC1_FPDCxxx_PMI_AREG     26768  ewis-SolarNE
#
#           PI_METHOD
# 0   GetArchiveValue
# 1   GetArchiveValue
# 2   GetArchiveValue
# 3   GetArchiveValue
# 4   GetArchiveValue
# 5   GetArchiveValue
# 6   GetArchiveValue
# 7   GetArchiveValue
# 8   GetArchiveValue
# 9   GetArchiveValue
# 10  GetArchiveValue
# 11  GetArchiveValue
# 12  GetArchiveValue
# 13  GetArchiveValue
# 14  GetArchiveValue
# 15  GetArchiveValue
# 16  GetArchiveValue
# 17  GetArchiveValue
# 18  GetArchiveValue
# 19  GetArchiveValue
# 20  GetArchiveValue
# 21  GetArchiveValue
# 22  GetArchiveValue
# 23  GetArchiveValue
# 24  GetArchiveValue
# 25  GetArchiveValue
# 26  GetArchiveValue
# 27  GetArchiveValue
# 28  GetArchiveValue
# 29  GetArchiveValue
# ..              ...
# 70  GetArchiveValue
# 71  GetArchiveValue
# 72  GetArchiveValue
# 73  GetArchiveValue
# 74  GetArchiveValue
# 75  GetArchiveValue
# 76  GetArchiveValue
# 77  GetArchiveValue
# 78  GetArchiveValue
# 79  GetArchiveValue
# 80  GetArchiveValue
# 81  GetArchiveValue
# 82  GetArchiveValue
# 83  GetArchiveValue
# 84  GetArchiveValue
# 85  GetArchiveValue
# 86  GetArchiveValue
# 87  GetArchiveValue
# 88  GetArchiveValue
# 89  GetArchiveValue
# 90  GetArchiveValue
# 91  GetArchiveValue
# 92  GetArchiveValue
# 93  GetArchiveValue
# 94  GetArchiveValue
# 95  GetArchiveValue
# 96  GetArchiveValue
# 97  GetArchiveValue
# 98  GetArchiveValue
# 99  GetArchiveValue
#
# [100 rows x 4 columns]

# %%
from datetime import datetime
from datetime import timedelta

min_date_resp = es_ods_conn.execute("""
select DISTINCT
MIN(TO_CHAR(TRUNC(timestamplocal), 'YYYY-MM-DD')) stg1_date
from es_ods_owner.es_scada_stg1
""")
# print(str(min_date_resp.fetchone()[0]))
print(datetime.strptime(str(min_date_resp.fetchone()[0]), "%Y-%m-%d").date())
# print(dt.datetime.strptime('2019-01-11', "%Y-%m-%d").date())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-310b970d7840> in <module>
#       2 from datetime import timedelta
#       3
# ----> 4 min_date_resp = es_ods_conn.execute("""
#       5 select DISTINCT
#       6 MIN(TO_CHAR(TRUNC(timestamplocal), 'YYYY-MM-DD')) stg1_date
#
# NameError: name 'es_ods_conn' is not defined

# %%
# 3. Expression: Add Time Fields
# Add End_Time, Incremenetal_Time, End_Date_Interpolated
# Using some $$START_TIME Parameter possibly set in configuration file?
from datetime import date, datetime, timedelta, time
from sqlalchemy.ext.declarative import declarative_base
from bs4 import BeautifulSoup

# Define configuration settinngs that can be used to control the queries that call the process:
INTERVAL = 1 # days
MINUTES = 1440 # 60 * 24 = # of minutes in a day


MINUTES_PER_DAY = 1440  # 60 * 24 = # of minutes in a day
IPR_MIN_INTERVAL = 10  # number of minutes per api pull
IPR_MIN_RANGE = int(MINUTES_PER_DAY / IPR_MIN_INTERVAL)

print(str(IPR_MIN_RANGE))

minutes_in_timerange = INTERVAL * MINUTES
today = datetime.utcnow().date()
start_dt = datetime.strptime('20190101', '%Y%m%d')
end_dt = datetime.strptime('20190101', '%Y%m%d')
# end_dt = datetime(today.year, today.month, today.day)
# start_dt = end_dt - timedelta(days=INTERVAL)
num_days = (end_dt - start_dt).days + 1
start_time = time()


daterange_dict = {i: (start_dt + timedelta(minutes=i*MINUTES_PER_DAY)).strftime('%Y-%m-%d') for i in range(num_days)}

timerange_dict = {i: (start_dt + timedelta(minutes=i)).time() for i in range(minutes_in_timerange)}

ipr_timerange_dict = { i: {
                            'START_TIME': ((start_dt + timedelta(minutes= i * IPR_MIN_INTERVAL)).time()).strftime('%H:%M:%S'),
                            'END_TIME': ((start_dt + timedelta(minutes= ((i + 1) * IPR_MIN_INTERVAL)-1)).time()).strftime('%H:%M:%S'),
                            'MINUTE_INTERVAL': IPR_MIN_INTERVAL
                        } for i in range(IPR_MIN_RANGE) }

#print(daterange_dict)

#print(timerange_dict)

# print(ipr_timerange_dict)

ipr_timerange_df = pd.DataFrame.from_dict(ipr_timerange_dict, orient='index', columns=['START_TIME', 'END_TIME', 'MINUTE_INTERVAL'])

#print(ipr_timerange_df.head(100))

daterange_df = pd.DataFrame.from_dict(daterange_dict, orient='index', columns=['DATE'])

datetime_df = daterange_df.assign(foo=1).merge(ipr_timerange_df.assign(foo=1)).drop('foo', 1)
datetime_df['START_DATETIME'] = datetime_df['DATE'] + " " + datetime_df['START_TIME']
datetime_df['END_DATETIME'] = datetime_df['DATE'] + " " + datetime_df['END_TIME']

print(datetime_df.head(500))


import requests
from datetime import datetime, timedelta, date


for rec in datetime_df.itertuples():

    start_time_str = rec.START_DATETIME
    end_time_str = rec.END_DATETIME

    start_datetime = datetime.strptime(start_time_str, '%Y-%m-%d %H:%M:%S')
    end_datetime = datetime.strptime(end_time_str, '%Y-%m-%d %H:%M:%S')

    time_diff = (end_datetime - start_datetime)
    day_diff = int(time_diff.days)
    print("NUM DAYS: " + str(day_diff))

    if day_diff > 0:
        days_to_mins = (day_diff * 24) * 60
    else:
        days_to_mins = 0

    print("DAYS TO MIN: " + str(days_to_mins))
    print((time_diff.seconds / 60) + 1)

    secs_to_mins = (time_diff.seconds / 60) + 1

    interval = str(int(days_to_mins + secs_to_mins))
    print(interval)

    url="http://matrix-piws.fpl.com/fplpiws/piws.asmx"
    #headers = {'content-type': 'application/soap+xml'}
    headers = {'content-type': 'text/xml'}
    body = """<?xml version="1.0" encoding="utf-8"?>
    <soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/" xmlns:fpl="http://fpl.pgen/">
       <soapenv:Header/>
       <soapenv:Body>
          <fpl:GetInterpolatedValues>
             <!--Optional:-->
             <fpl:serverName>ewis-battne</fpl:serverName>
             <!--Optional:-->
             <fpl:pointName>BMY_BATTxxx_SUB0001_KW_Total</fpl:pointName>
             <!--Optional:-->
             <fpl:startTime>{StartTime}</fpl:startTime>
             <!--Optional:-->
             <fpl:endTime>{EndTime}</fpl:endTime>
             <fpl:intervals>{Interval}</fpl:intervals>
          </fpl:GetInterpolatedValues>
       </soapenv:Body>
    </soapenv:Envelope>""".format(StartTime=start_time_str, EndTime=end_time_str, Interval=interval)

    response = requests.post(url,data=body,headers=headers)
}
# NUM DAYS: 0
# DAYS TO MIN: 0
# 10.0
# 10
# {'Timestamp': '2019-01-01T23:30:00', 'Value': '-13303.986328125'}
# {'Timestamp': '2019-01-01T23:31:00', 'Value': '-13286.490234375'}
# {'Timestamp': '2019-01-01T23:32:00', 'Value': '-13306.291015625'}
# {'Timestamp': '2019-01-01T23:33:00', 'Value': '7565.30078125'}
# {'Timestamp': '2019-01-01T23:34:00', 'Value': '13160.3056640625'}
# {'Timestamp': '2019-01-01T23:35:00', 'Value': '9290.91015625'}
# {'Timestamp': '2019-01-01T23:36:00', 'Value': '-13294.2333984375'}
# {'Timestamp': '2019-01-01T23:37:00', 'Value': '-13290.568359375'}
# {'Timestamp': '2019-01-01T23:38:00', 'Value': '1758.6134033203125'}
# {'Timestamp': '2019-01-01T23:39:00', 'Value': '13299.74609375'}
# NUM DAYS: 0
# DAYS TO MIN: 0
# 10.0
# 10
# {'Timestamp': '2019-01-01T23:40:00', 'Value': '12577.310546875'}
# {'Timestamp': '2019-01-01T23:41:00', 'Value': '11971.9873046875'}
# {'Timestamp': '2019-01-01T23:42:00', 'Value': '11308.98828125'}
# {'Timestamp': '2019-01-01T23:43:00', 'Value': '-11715.98828125'}
# {'Timestamp': '2019-01-01T23:44:00', 'Value': '-13255.2685546875'}
# {'Timestamp': '2019-01-01T23:45:00', 'Value': '-13307.0810546875'}
# {'Timestamp': '2019-01-01T23:46:00', 'Value': '-3185.813720703125'}
# {'Timestamp': '2019-01-01T23:47:00', 'Value': '-1040.36767578125'}
# {'Timestamp': '2019-01-01T23:48:00', 'Value': '-2567.54833984375'}
# {'Timestamp': '2019-01-01T23:49:00', 'Value': '-1045.0899658203125'}
# NUM DAYS: 0
# DAYS TO MIN: 0
# 10.0
# 10
# {'Timestamp': '2019-01-01T23:50:00', 'Value': '-13204.3466796875'}
# {'Timestamp': '2019-01-01T23:51:00', 'Value': '-12643.076171875'}
# {'Timestamp': '2019-01-01T23:52:00', 'Value': '-2281.909423828125'}
# {'Timestamp': '2019-01-01T23:53:00', 'Value': '8952.734375'}
# {'Timestamp': '2019-01-01T23:54:00', 'Value': '-10019.990234375'}
# {'Timestamp': '2019-01-01T23:55:00', 'Value': '-11346.98828125'}
# {'Timestamp': '2019-01-01T23:56:00', 'Value': '-3823.99609375'}
# {'Timestamp': '2019-01-01T23:57:00', 'Value': '8547.623046875'}
# {'Timestamp': '2019-01-01T23:58:00', 'Value': '12953.5810546875'}
# {'Timestamp': '2019-01-01T23:59:00', 'Value': '1700.076416015625'}

# %%
# Need to create a table schema:

engine = create_engine('sqlite:///esbi.db')

Base = declarative_base()

class DateRange(Base):
    __tablename__ = 'date_range'

    DateId = Column(Integer, primary_key=True)
    DateStr = Column(String(255))
    DateVal = Column(DateTime)

    '''
    def __init__(self, date_id, date_str, date_val):
        self.DateId = date_id
        self.DateStr = date_str
        self.DateVal = date_val
    '''

    def __repr__(self):
        return "<DateRange('%s')>" % (self.DateStr)
        
DateRange.__table__.create(bind=engine, checkfirst=True)

# %%
# Writing date range to sqlite table:

from datetime import datetime, timedelta

dateranges = []

for key, value in timerange_list.items():
    row = {}
    row['DateId'] = key
    row['DateStr'] = value.strftime('%Y-%m-%d %H:%M:%S')
    row['DateVal'] = value
    # print(row)
    dateranges.append(row)
    

# Commit to a local table:
'''
from sqlalchemy.orm import sessionmaker
    
Session = sessionmaker(bind=engine)
session = Session() 

for date_interval in dateranges:
    row = DateRange(**date_interval)
    session.add(row)
    
session.commit()

# Review dates import into sqlite db esbi.db:
connection = engine.connect()
metadata = MetaData()
dateranges = Table('date_range', metadata, autoload=True, autoload_with=engine)


# Print the column names
print(dateranges.columns.keys())

# Print full table metadata
print(repr(metadata.tables['date_range']))

#Equivalent to 'SELECT * FROM date_range'
query = select([dateranges])

ResultProxy = connection.execute(query)

ResultSet = ResultProxy.fetchall()

print(ResultSet[:50])
'''

daterange_df = pd.DataFrame(dateranges)
daterange_df.head(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-aad985ea4865> in <module>
#       5 dateranges = []
#       6
# ----> 7 for key, value in timerange_list.items():
#       8     row = {}
#       9     row['DateId'] = key
#
# NameError: name 'timerange_list' is not defined

# %%
# Merge the two dataframes:
from pandas import DataFrame, merge
import dask.dataframe as dd



daterange_df = pd.DataFrame.from_dict(daterange_dict, orient='index')
timerange_df = pd.DataFrame.from_dict(timerange_dict, orient='index')
datetime_df = daterange_df.assign(foo=1).merge(timerange_df.assign(foo=1)).drop('foo', 1)

print(datetime_df)

""""
for plant_id in es_tags_df['PLANT_ID'].unique():
    
    print(str(plant_id) + ": ")
    
    for tag in es_tags_df[es_tags_df['PLANT_ID'] == int(plant_id)]['TAG_NAME']:
        
        print("\t" + str(tag))
"""
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-76a402246f3e> in <module>
#       7 daterange_df = pd.DataFrame.from_dict(daterange_dict, orient='index')
#       8 timerange_df = pd.DataFrame.from_dict(timerange_dict, orient='index')
# ----> 9 datetime_df = daterange_df.assign(foo=1).merge(timerange_df.assign(foo=1)).drop('foo', 1)
#      10
#      11 print(datetime_df)
#
# c:\users\oxr0mqy\envs\jupyter_testing\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6387                      right_on=right_on, left_index=left_index,
#    6388                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6389                      copy=copy, indicator=indicator, validate=validate)
#    6390
#    6391     def round(self, decimals=0, *args, **kwargs):
#
# c:\users\oxr0mqy\envs\jupyter_testing\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          right_index=right_index, sort=sort, suffixes=suffixes,
#      60                          copy=copy, indicator=indicator,
# ---> 61                          validate=validate)
#      62     return op.get_result()
#      63
#
# c:\users\oxr0mqy\envs\jupyter_testing\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     553         # validate the merge keys dtypes. We may need to coerce
#     554         # to avoid incompat dtypes
# --> 555         self._maybe_coerce_merge_keys()
#     556
#     557         # If argument passed to validate,
#
# c:\users\oxr0mqy\envs\jupyter_testing\lib\site-packages\pandas\core\reshape\merge.py in _maybe_coerce_merge_keys(self)
#     986                 raise ValueError(msg)
#     987             elif is_datetimelike(lk) and not is_datetimelike(rk):
# --> 988                 raise ValueError(msg)
#     989             elif not is_datetimelike(lk) and is_datetimelike(rk):
#     990                 raise ValueError(msg)
#
# ValueError: You are trying to merge on datetime64[ns] and object columns. If you wish to proceed you should use pd.concat

# %%
for plant_id in es_tags_df['PLANT_ID'].unique():
    
    print(str(plant_id) + ": ")
    
    # for rec in es_tags_df.loc[ (es_tags_df['PLANT_ID'] == int(plant_id)), ['TAG_NAME'] ].itertuples():
        
        # print(rec.TAG_NAME)
    print((es_tags_df.loc[ (es_tags_df['PLANT_ID'] == int(plant_id)), ['TAG_NAME'] ]).assign(foo=1).merge(daterange_df.assign(foo=1)).merge(timerange_df.assign(foo=1)).drop('foo', 1))
        
    tags_tf_df = es_tags_df.loc[ (es_tags_df['PLANT_ID'] == int(plant_id)), ['TAG_NAME'] ].assign(foo=1).merge(timerange_df.assign(foo=1)).drop('foo', 1)
    print(tags_tf_df.head(100))

# %%
# 4. Router
# Splits data flow for the two types of API PI_Method calls: 'GetArchiveValue', 'GetInterpolatedValues'
# 'GetArchiveValue': returns a single xml record instance
# 'GetInterpolatedValues': returns multiple xml records from API

# Define a ditionary with the API Settings per type:
rtr_pi_method_config = {
   'GetArchiveValue': """
       <soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/" xmlns:fpl="http://fpl.pgen/">
       <soapenv:Header/>
       <soapenv:Body>
          <fpl:GetArchiveValue>
             <!--Optional:-->
             <fpl:sServerName>{ServerName}</fpl:sServerName>
             <!--Optional:-->
             <fpl:sPointName>{PointName}</fpl:sPointName>
             <!--Optional:-->
             <fpl:sTimeStamp>{startTime}</fpl:sTimeStamp>
          </fpl:GetArchiveValue>
       </soapenv:Body>
    </soapenv:Envelope>
    """,
    'GetInterpolatedValues': """
        <soapenv:Envelope xmlns:soapenv="http://schemas.xmlsoap.org/soap/envelope/" xmlns:fpl="http://fpl.pgen/">
        <soapenv:Header/>
        <soapenv:Body>
          <fpl:GetInterpolatedValues>
             <!--Optional:-->
             <fpl:serverName>{ServerName}</fpl:serverName>
             <!--Optional:-->
             <fpl:pointName>{PointName}</fpl:pointName>
             <!--Optional:-->
             <fpl:startTime>{startTime}</fpl:startTime>
             <!--Optional:-->
             <fpl:endTime>{endTime}</fpl:endTime>
             <fpl:intervals>{Interval}</fpl:intervals>
          </fpl:GetInterpolatedValues>
       </soapenv:Body>
    </soapenv:Envelope>
    """
}

# %%
# 5. HTTP Extract:
# Make respective calls to the API
# MAKE SOAP REQUEST: GetArchiveValue
import requests
# Parse response for the needed values to load into STG1 table:
from bs4 import BeautifulSoup
import datetime

delim = ','
url="http://matrix-piws.fpl.com/fplpiws/piws.asmx"
headers = {'content-type': 'text/xml'}

#val_dict = dict.fromkeys(['SERVERNAME','TAGNAME','TIMESTAMP','VALUE', 'VALUESTRING'])
output_headers = ('SERVERNAME','TAGNAME','TIMESTAMP','VALUE', 'VALUESTRING')
final_out = []
final_out.append(output_headers)

for INDEX, rec in tags_tf_df.iterrows():
    
    # print(rec)
    
    # Make request to the API using the SOAP pattern defined above:
    if rec['PI_METHOD'] == 'GetArchiveValue':
        body = rtr_pi_method_config['GetArchiveValue'].format(ServerName=rec['SERVER_NAME'], PointName=rec['TAG_NAME'], startTime=rec['DateStr'])
    elif rec['PI_METHOD'] == 'GetInterpolatedValues':
        body = rtr_pi_method_config['GetInterpolatedValues'].format(ServerName=rec.server_name, PointName=rec.tag_name, startTime=rec.start_time, endTime=rec.end_time, Interval=rec.interval)
    
    try:
        response = requests.post(url,data=body,headers=headers)
        
        xml = response.content
        soup = BeautifulSoup(xml, 'lxml')
        # print(soup)
        print()
        print('DICT: ')
        # print(rec['SERVER_NAME']+delim+rec['TAG_NAME']+delim+rec['DateStr']+delim+soup.body.value.text+delim+soup.body.valuestring.text)
        final_out.append((rec['SERVER_NAME'],rec['TAG_NAME'],rec['DateStr'],soup.body.value.text,soup.body.valuestring.text))
        scada_stg1_record = dict(plant_id=rec['SERVER_NAME'],
                                    plant_code=rec['TAG_NAME'],
                                    timestamplocal=rec['DateStr'],
                                    timestamputc=datetime.datetime.utcnow(),
                                    value=soup.body.value.text,
                                    create_date=datetime.datetime.now(),
                                    update_date=datetime.datetime.now(),
                                    created_by='ES_ODS_OWNER',
                                    updated_by='ES_ODS_OWNER')
        print(scada_stg1_record)
        
    except:
        continue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-beb9cd58d07b> in <module>
#      16 final_out.append(output_headers)
#      17
# ---> 18 for INDEX, rec in tags_tf_df.iterrows():
#      19
#      20     # print(rec)
#
# NameError: name 'tags_tf_df' is not defined

# %%
# Need to parse records into xml records that can be uploaded to S3 and then processed into csv files for load into RedShift:
for row in final_out:
    print(row)

# %%
# need to extract the fields values into the STG1 Table:
# Need to define SQL Queries per table:
# Reflect the tables from the connection
from sqlalchemy.sql import text

# es_dw_conn.close()

orc_es_ods_engine = create_engine('oracle://ES_ODS_OWNER:yD8J;Czg@PGSDWD')

es_ods_conn = orc_es_ods_engine.connect()

statement = text("""
                    select distinct 
                    plant_id, 
                    tagname, 
                    TRUNC(timestamplocal) as "date", 
                    count(*) as "count"
                    from es_scada_stg1 
                    where TRUNC(timestamplocal) >= TO_DATE('01-OCT-18', 'DD-MON-RR') 
                    AND plant_id = {PlantId} and tagname = '{TagName}' 
                    group by plant_id, tagname, TRUNC(timestamplocal)
                """.format(PlantId=34044, TagName='BCB_BATTxxx_SUB0001_ISO_AREG_LOW'))
values = es_ods_conn.execute(statement)
df = pd.DataFrame(values.fetchall())
df.columns = [k.upper() for k in values.keys()] 

print(df)

es_ods_metadata = MetaData()
es_ods_metadata.reflect(orc_es_ods_engine)

# we can then produce a set of mappings from this MetaData.
es_ods_base = automap_base(metadata=es_ods_metadata)

# calling prepare() just sets up mapped classes and relationships.
es_ods_base.prepare()
# Out:
#     PLANT_ID                                    TAGNAME       date  count
# 0      34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-27   1440
# 1      34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-22   1440
# 2      34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-23   1440
# 3      34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-13   1439
# 4      34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-11   1440
# 5      34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-15   1440
# 6      34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-31   1440
# 7      34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-30   1440
# 8      34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-28   1440
# 9      34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-24   1440
# 10     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-07   1440
# 11     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-02   1440
# 12     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-11-01      2
# 13     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-26   1440
# 14     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-29   1440
# 15     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-16   1440
# 16     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-10   1440
# 17     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-09   1440
# 18     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-20   1440
# 19     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-17   1440
# 20     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-14   1440
# 21     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-12   1440
# 22     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-08   1440
# 23     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-06   1440
# 24     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-05   1440
# 25     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-19   1440
# 26     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-18   1440
# 27     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-04   1440
# 28     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-25   1440
# 29     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-21   1440
# 30     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-03   1440
# 31     34044  BMY_BATTxxx_SUB0001_52M2_Breaker_Position 2018-10-01   1438

# %%
# oNLY REFLECTS TABLES WITH A PRIMARY KEY?
for tablename in es_ods_base.classes:
    print(tablename)
